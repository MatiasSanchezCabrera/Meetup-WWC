# %% [markdown]
# # Importar y ver el conjunto de datos

# %%
import pandas as pd

# %%
import pandas as pd
dataset = pd.read_csv('http://www.datalized.cl/iris/')

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
print "{} observaciones".format(len(dataset))
print "{} clases".format(len(dataset['species'].unique()))
# Out:
# 150 observaciones
# 3 clases

# %% [markdown]
# # Entrenar un árbol de decisión

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
X = dataset[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y = dataset[['species']]

# %%
model.fit(X, Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
X[:1]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2

# %%
pred = model.predict(X[:1])
print pred
# Out:
# ['setosa']

# %%
Y[:1]
# Out:
#   species
# 0  setosa

# %% [markdown]
# # Entrenar un SVM y una Red Neuronal

# %%
from sklearn import svm
from sklearn import neural_network

# %%
model = svm.SVC()
model.fit(X, Y)
model.predict(X[:1])
# Out:
# /Users/matias/miniconda2/envs/wwc/lib/python2.7/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['setosa'], dtype=object)

# %%
model = neural_network.MLPClassifier()
model.fit(X, Y)
model.predict(X[:1])
# Out:
# /Users/matias/miniconda2/envs/wwc/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:912: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/matias/miniconda2/envs/wwc/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# array(['setosa'], dtype='|S10')

# %% [markdown]
# # Metodología para evaluar cual modelo es mejor

# %%
from sklearn import model_selection

# %%
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, train_size=0.7)
# Out:
# /Users/matias/miniconda2/envs/wwc/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)
print "{} accuracy for model {}".format(metrics.accuracy_score(y_test, pred), model)
# Out:
# 0.955555555556 accuracy for model DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model = svm.SVC()
model.fit(X_train, y_train)
pred = model.predict(X_test)
print "{} accuracy for model {}".format(metrics.accuracy_score(y_test, pred), model)
# Out:
# 0.977777777778 accuracy for model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
model = neural_network.MLPClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)
print "{} accuracy for model {}".format(metrics.accuracy_score(y_test, pred), model)
# Out:
# 0.977777777778 accuracy for model MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
